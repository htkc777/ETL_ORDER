# %%
! pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:\\Users\\15442\\Desktop\\Files\\ETL Through Code\\Modified files\\1st Table\\Stage1_Sales_SAL_SOBKNG_TB(m).csv')
# Out:
# C:\Users\15442\AppData\Local\Temp\ipykernel_14276\661781421.py:1: DtypeWarning: Columns (18,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('C:\\Users\\15442\\Desktop\\Files\\ETL Through Code\\Modified files\\1st Table\\Stage1_Sales_SAL_SOBKNG_TB(m).csv')

# %%
df2 = pd.read_csv('C:\\Users\\15442\\Desktop\\Files\\ETL Through Code\\Modified files\\1st Table\\MOB_Docket_Date(m).csv')

# %%
df1.shape
# Out:
# (953389, 35)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953389 entries, 0 to 953388
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Dealer_No              953388 non-null  object
#  1   Booking_No             953388 non-null  object
#  2   Corporation_No         953388 non-null  object
#  3   Company_No             953388 non-null  object
#  4   BKNG_DATE              953388 non-null  object
#  5   Model_Code             953388 non-null  object
#  6   TRIM_Code              953388 non-null  float64
#  7   Ext.Colour_Code        953387 non-null  object
#  8   BKNG_EXPCT_DLVRY_DATE  167443 non-null  float64
#  9   BKNG_VRNT_PRICE        942063 non-null  float64
#  10  Booking_Amt            953389 non-null  int64
#  11  BKNG_RCPT_TOTAL_AMT    906449 non-null  float64
#  12  BKNG_ALCN_DATE         507786 non-null  object
#  13  BKNG_FNCE_TYPE         943447 non-null  float64
# ...

# %%
df2.shape
# Out:
# (953461, 3)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953461 entries, 0 to 953460
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   MOB_EMAIL_DATE  256450 non-null  object
#  1   DMS_EMAIL_DATE  429549 non-null  object
#  2   Dealer_Booking  953460 non-null  object
# dtypes: object(3)
# memory usage: 21.8+ MB

# %%
df3 = df2.copy()

# %%
df3.drop(['DMS_EMAIL_DATE'], axis=1, inplace = True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953461 entries, 0 to 953460
# Data columns (total 2 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   MOB_EMAIL_DATE  256450 non-null  object
#  1   Dealer_Booking  953460 non-null  object
# dtypes: object(2)
# memory usage: 14.5+ MB

# %%
df3
# Out:
#              MOB_EMAIL_DATE     Dealer_Booking
# 0                       NaN  TRUP403B201900001
# 1                       NaN  TRUP403B201900009
# 2                       NaN  TRUP403B201900044
# 3       2020-11-09 12:07:00  TRUP403B202002961
# 4                       NaN  TRUP403B201900011
# ...                     ...                ...
# 953456  2022-06-08 17:17:00  TRHP501B202201066
# 953457                  NaN  TRMH502B202201296
# 953458  2022-06-08 16:22:00  TRMH404B202204636
# 953459                  NaN  TRKA304B202208511
# 953460                  NaN  TRJH501B202200585
#
# [953461 rows x 2 columns]

# %%
# https://stackoverflow.com/questions/26258996/can-one-perform-a-left-join-in-pandas-that-selects-only-the-first-match-on-the-r

df4 = pd.merge(df1, df3, how='left', on=['Dealer_Booking']).groupby(['Dealer_Booking']).first().reset_index()
# appMap1= df4.groupby(['Dealer_Booking'])['MOB_EMAIL_DATE'].first().reset_index()
# appMap1

# %%
df4.head()
# Out:
#       Dealer_Booking Dealer_No  Booking_No Corporation_No Company_No  \
# 0  TRAP301B201900001   TRAP301  B201900001          A10VA          K
# 1  TRAP301B201900002   TRAP301  B201900002          A10VA          K
# 2  TRAP301B201900003   TRAP301  B201900003          A10VA          K
# 3  TRAP301B201900004   TRAP301  B201900004          A10VA          K
# 4  TRAP301B201900005   TRAP301  B201900005          A10VA          K
#
#     BKNG_DATE Model_Code  TRIM_Code Ext.Colour_Code  BKNG_EXPCT_DLVRY_DATE  \
# 0  2019-08-14         TI        2.0             GWP                    NaN
# 1  2019-08-16         TI        7.0             GWP                    NaN
# 2  2019-08-16         TI        4.0             GWP                    NaN
# 3  2019-08-16         TI        4.0             KDG                    NaN
# 4  2019-08-16         TI       15.0             A6R                    NaN
#
#    ...  Int.Colour_Code  BKNG_BILL_TO_STATE  BKNG_BILL_TO_CITY  \
# ...

# %%
df4.shape
# Out:
# (953387, 36)

# %%
result = df4[df4['Dealer_Booking']=='TRUP304B202102356']

# %%
result
# Out:
#            Dealer_Booking Dealer_No  Booking_No Corporation_No Company_No  \
# 876429  TRUP304B202102356   TRUP304  B202102356          A10VA          K
#
#          BKNG_DATE Model_Code  TRIM_Code Ext.Colour_Code  \
# 876429  2021-03-31         TI      294.0             GB2
#
#         BKNG_EXPCT_DLVRY_DATE  ...  Int.Colour_Code  BKNG_BILL_TO_STATE  \
# 876429                    NaN  ...               WK                None
#
#         BKNG_BILL_TO_CITY BKNG_BILL_TO_TEHSIL  BKNG_BILL_TO_VILLAGE  \
# 876429               None                None                  None
#
#        BKNG_RMRKS  BKNG_SRC_FLG  Booking_Source_Type Booking_Source  \
# 876429       None          None                  DMS            NAN
#
#              MOB_EMAIL_DATE
# 876429  2021-03-31 12:28:00
#
# [1 rows x 36 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953461 entries, 0 to 953460
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   MOB_EMAIL_DATE  256450 non-null  object
#  1   DMS_EMAIL_DATE  429549 non-null  object
#  2   Dealer_Booking  953460 non-null  object
# dtypes: object(3)
# memory usage: 21.8+ MB

# %%
df5 = df2.copy()

# %%
df5.drop(['MOB_EMAIL_DATE'], axis=1, inplace = True)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953461 entries, 0 to 953460
# Data columns (total 2 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DMS_EMAIL_DATE  429549 non-null  object
#  1   Dealer_Booking  953460 non-null  object
# dtypes: object(2)
# memory usage: 14.5+ MB

# %%
df5
# Out:
#              DMS_EMAIL_DATE     Dealer_Booking
# 0                       NaN  TRUP403B201900001
# 1                       NaN  TRUP403B201900009
# 2                       NaN  TRUP403B201900044
# 3                       NaN  TRUP403B202002961
# 4                       NaN  TRUP403B201900011
# ...                     ...                ...
# 953456                  NaN  TRHP501B202201066
# 953457  2022-06-08 18:12:00  TRMH502B202201296
# 953458  2022-06-08 16:16:00  TRMH404B202204636
# 953459                  NaN  TRKA304B202208511
# 953460                  NaN  TRJH501B202200585
#
# [953461 rows x 2 columns]

# %%
df6 = pd.merge(df4, df5, how='left', on=['Dealer_Booking']).groupby(['Dealer_Booking']).first().reset_index()

# %%
df6.head()
# Out:
#       Dealer_Booking Dealer_No  Booking_No Corporation_No Company_No  \
# 0  TRAP301B201900001   TRAP301  B201900001          A10VA          K
# 1  TRAP301B201900002   TRAP301  B201900002          A10VA          K
# 2  TRAP301B201900003   TRAP301  B201900003          A10VA          K
# 3  TRAP301B201900004   TRAP301  B201900004          A10VA          K
# 4  TRAP301B201900005   TRAP301  B201900005          A10VA          K
#
#     BKNG_DATE Model_Code  TRIM_Code Ext.Colour_Code  BKNG_EXPCT_DLVRY_DATE  \
# 0  2019-08-14         TI        2.0             GWP                    NaN
# 1  2019-08-16         TI        7.0             GWP                    NaN
# 2  2019-08-16         TI        4.0             GWP                    NaN
# 3  2019-08-16         TI        4.0             KDG                    NaN
# 4  2019-08-16         TI       15.0             A6R                    NaN
#
#    ...  BKNG_BILL_TO_STATE  BKNG_BILL_TO_CITY  BKNG_BILL_TO_TEHSIL  \
# ...

# %%
df6.shape
# Out:
# (953387, 37)

# %%
result1 = df6[df6['Dealer_Booking']=='TRTN102B202103016']

# %%
result1
# Out:
#            Dealer_Booking Dealer_No  Booking_No Corporation_No Company_No  \
# 723911  TRTN102B202103016   TRTN102  B202103016          A10VA          K
#
#          BKNG_DATE Model_Code  TRIM_Code Ext.Colour_Code  \
# 723911  2021-10-25         SX      372.0             GWP
#
#         BKNG_EXPCT_DLVRY_DATE  ...  BKNG_BILL_TO_STATE  BKNG_BILL_TO_CITY  \
# 723911                    NaN  ...                None               None
#
#         BKNG_BILL_TO_TEHSIL BKNG_BILL_TO_VILLAGE  BKNG_RMRKS BKNG_SRC_FLG  \
# 723911                 None                 None        None          MOB
#
#         Booking_Source_Type  Booking_Source       MOB_EMAIL_DATE  \
# 723911              MySales          MOBILE  2021-10-27 14:17:00
#
#              DMS_EMAIL_DATE
# 723911  2022-01-13 11:34:00
#
# [1 rows x 37 columns]

# %%
df6['Date'] = pd.to_datetime(df6['BKNG_DATE'], format='%Y-%m-%d').dt.strftime('%d/%m/%Y')

# %%
df6['Date']
# Out:
# 0         14/08/2019
# 1         16/08/2019
# 2         16/08/2019
# 3         16/08/2019
# 4         16/08/2019
#              ...
# 953382    15/07/2022
# 953383    15/07/2022
# 953384    18/07/2022
# 953385    25/07/2022
# 953386    05/08/2022
# Name: Date, Length: 953387, dtype: object

# %%
df6
# Out:
#            Dealer_Booking Dealer_No  Booking_No Corporation_No Company_No  \
# 0       TRAP301B201900001   TRAP301  B201900001          A10VA          K
# 1       TRAP301B201900002   TRAP301  B201900002          A10VA          K
# 2       TRAP301B201900003   TRAP301  B201900003          A10VA          K
# 3       TRAP301B201900004   TRAP301  B201900004          A10VA          K
# 4       TRAP301B201900005   TRAP301  B201900005          A10VA          K
# ...                   ...       ...         ...            ...        ...
# 953382  TRWB501B202200105   TRWB501  B202200105          A10VA          K
# 953383  TRWB501B202200106   TRWB501  B202200106          A10VA          K
# 953384  TRWB501B202200107   TRWB501  B202200107          A10VA          K
# 953385  TRWB501B202200108   TRWB501  B202200108          A10VA          K
# 953386  TRWB501B202200109   TRWB501  B202200109          A10VA          K
#
#          Link_Date Model_Code  TRIM_Code Ext.Colour_Code  \
# ...

# %%
df6.rename(columns = {'Date':'Booking_Date'}, inplace = True)

# %%
df6.rename(columns = {'BKNG_DATE':'Link_Date'}, inplace = True)

# %%
df6['Booking_Amt']
# Out:
# 0         25000
# 1             0
# 2             0
# 3             0
# 4             0
#           ...
# 953382        0
# 953383        0
# 953384        0
# 953385        0
# 953386        0
# Name: Booking_Amt, Length: 953387, dtype: int64

# %%
df6['Booking_Status'] = df6['Booking_Amt'].apply(lambda x: 'Without Payment' if x == 0 else 'Payment')

# %%
df6
# Out:
#            Dealer_Booking Dealer_No  Booking_No Corporation_No Company_No  \
# 0       TRAP301B201900001   TRAP301  B201900001          A10VA          K
# 1       TRAP301B201900002   TRAP301  B201900002          A10VA          K
# 2       TRAP301B201900003   TRAP301  B201900003          A10VA          K
# 3       TRAP301B201900004   TRAP301  B201900004          A10VA          K
# 4       TRAP301B201900005   TRAP301  B201900005          A10VA          K
# ...                   ...       ...         ...            ...        ...
# 953382  TRWB501B202200105   TRWB501  B202200105          A10VA          K
# 953383  TRWB501B202200106   TRWB501  B202200106          A10VA          K
# 953384  TRWB501B202200107   TRWB501  B202200107          A10VA          K
# 953385  TRWB501B202200108   TRWB501  B202200108          A10VA          K
# 953386  TRWB501B202200109   TRWB501  B202200109          A10VA          K
#
#          Link_Date Model_Code  TRIM_Code Ext.Colour_Code  \
# ...

# %%
df6.shape
# Out:
# (953387, 39)
