# %%
! pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\15442\\Desktop\\Files\\ETL Through Code\\RAW files\\Stage1_Sales_RO_Booking.csv')
# Out:
# C:\Users\15442\AppData\Local\Temp\ipykernel_8092\2888855340.py:1: DtypeWarning: Columns (31,39,96) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:\\Users\\15442\\Desktop\\Files\\ETL Through Code\\RAW files\\Stage1_Sales_RO_Booking.csv')

# %%
df.shape
# Out:
# (953461, 105)

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953461 entries, 0 to 953460
# Data columns (total 105 columns):
#  #    Column                  Dtype
# ---   ------                  -----
#  0    Occup_Key               object
#  1    CMM_CODE                float64
#  2    Comp_key                object
#  3    EQRY_MAKER_CODE         object
#  4    Join_KEY                object
#  5    CSPM_CHRG_SALES_EMP_NO  object
#  6    Booking Month           object
#  7    REGION                  object
#  8    BKNG_DLR_NO             object
#  9    TRADE_NAME              object
#  10   DEALER_CITY             object
#  11   EQRY_ENQRY_NO           object
#  12   EQRY_PRESENT_CAR_YN     object
#  13   EQRY_DATE               object
#  14   EQRY_STAT               object
#  15   EQRY_CLSE_DATE          object
#  16   EQRY_SRC_CODE           object
#  17   EQRY_CTGR_CODE          float64
#  18   EQRY_SUB_SRC_CODE       object
#  19   CSPM_CUST_NO            object
# ...

# %%
df['Dealer_Booking'] = df['BKNG_DLR_NO'] + df['BKNG_NO']

# %%
df['Dealer_Booking']
# Out:
# 0         TRUP403B201900001
# 1         TRUP403B201900009
# 2         TRUP403B201900044
# 3         TRUP403B202002961
# 4         TRUP403B201900011
#                 ...
# 953456    TRHP501B202201066
# 953457    TRMH502B202201296
# 953458    TRMH404B202204636
# 953459    TRKA304B202208511
# 953460    TRJH501B202200585
# Name: Dealer_Booking, Length: 953461, dtype: object

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953461 entries, 0 to 953460
# Data columns (total 106 columns):
#  #    Column                  Dtype
# ---   ------                  -----
#  0    Occup_Key               object
#  1    CMM_CODE                float64
#  2    Comp_key                object
#  3    EQRY_MAKER_CODE         object
#  4    Join_KEY                object
#  5    CSPM_CHRG_SALES_EMP_NO  object
#  6    Booking Month           object
#  7    REGION                  object
#  8    BKNG_DLR_NO             object
#  9    TRADE_NAME              object
#  10   DEALER_CITY             object
#  11   EQRY_ENQRY_NO           object
#  12   EQRY_PRESENT_CAR_YN     object
#  13   EQRY_DATE               object
#  14   EQRY_STAT               object
#  15   EQRY_CLSE_DATE          object
#  16   EQRY_SRC_CODE           object
#  17   EQRY_CTGR_CODE          float64
#  18   EQRY_SUB_SRC_CODE       object
#  19   CSPM_CUST_NO            object
# ...

# %%
list = []
for i in df:
    if i != 'Dealer_Booking' and i != 'MOB_EMAIL_DATE' and i!= 'DMS_EMAIL_DATE':
        list.append(i)

# %%
list
# Out:
# ['Occup_Key',
#  'CMM_CODE',
#  'Comp_key',
#  'EQRY_MAKER_CODE',
#  'Join_KEY',
#  'CSPM_CHRG_SALES_EMP_NO',
#  'Booking Month',
#  'REGION',
#  'BKNG_DLR_NO',
#  'TRADE_NAME',
#  'DEALER_CITY',
#  'EQRY_ENQRY_NO',
#  'EQRY_PRESENT_CAR_YN',
#  'EQRY_DATE',
#  'EQRY_STAT',
#  'EQRY_CLSE_DATE',
#  'EQRY_SRC_CODE',
#  'EQRY_CTGR_CODE',
#  'EQRY_SUB_SRC_CODE',
#  'CSPM_CUST_NO',
#  'CSPM_CUST_FULL_NAME',
#  'M_MOBL_PHONE_NO',
#  'CSPM_EMAIL',
#  'CUSTOMER_TYPE',
#  'MODEL',
#  'ENGINE_TYPE',
#  'TRANSMISSION',
#  'TRANSMISSION1',
#  'KEC',
#  'KEC_CODE',
#  'ADDR',
#  'PIN_CODE',
#  'CITY_CODE',
#  'STCD_CODE',
#  'BOOKING_ADD1',
#  'BOOKING_ADD2',
#  'BOOKING_ADD3',
#  'BOOKING_STATE',
#  'BOOKING_CITY',
#  'BOOKING_PIN',
#  'EXCHANGE_REQUIRED',
#  'EQRY_EXCHG_MODEL_CODE',
#  'EQRY_EXCHG_SRC_CODE',
#  'EQRY_CORP_NAME',
#  'EQRY_EXPCT_PRICE',
#  'EQRY_QUOTD_PRICE',
#  'EQRY_P_MODL_YEAR',
#  'EQRY_EVAL_YN',
#  'EQRY_EXCH_DN',
#  'EQRY_FINAL_BP',
#  'EQRY_CMPN_NO',
#  'EQRY_CORP_NO',
# ...

# %%
df.drop(['Occup_Key',
 'CMM_CODE',
 'Comp_key',
 'EQRY_MAKER_CODE',
 'Join_KEY',
 'CSPM_CHRG_SALES_EMP_NO',
 'Booking Month',
 'REGION',
 'BKNG_DLR_NO',
 'TRADE_NAME',
 'DEALER_CITY',
 'EQRY_ENQRY_NO',
 'EQRY_PRESENT_CAR_YN',
 'EQRY_DATE',
 'EQRY_STAT',
 'EQRY_CLSE_DATE',
 'EQRY_SRC_CODE',
 'EQRY_CTGR_CODE',
 'EQRY_SUB_SRC_CODE',
 'CSPM_CUST_NO',
 'CSPM_CUST_FULL_NAME',
 'M_MOBL_PHONE_NO',
 'CSPM_EMAIL',
 'CUSTOMER_TYPE',
 'MODEL',
 'ENGINE_TYPE',
 'TRANSMISSION',
 'TRANSMISSION1',
 'KEC',
 'KEC_CODE',
 'ADDR',
 'PIN_CODE',
 'CITY_CODE',
 'STCD_CODE',
 'BOOKING_ADD1',
 'BOOKING_ADD2',
 'BOOKING_ADD3',
 'BOOKING_STATE',
 'BOOKING_CITY',
 'BOOKING_PIN',
 'EXCHANGE_REQUIRED',
 'EQRY_EXCHG_MODEL_CODE',
 'EQRY_EXCHG_SRC_CODE',
 'EQRY_CORP_NAME',
 'EQRY_EXPCT_PRICE',
 'EQRY_QUOTD_PRICE',
 'EQRY_P_MODL_YEAR',
 'EQRY_EVAL_YN',
 'EQRY_EXCH_DN',
 'EQRY_FINAL_BP',
 'EQRY_CMPN_NO',
 'EQRY_CORP_NO',
 'EQRY_LISTD_CORP',
 'EQRY_CUST_NO',
 'EQRY_DLR_NO',
 'CSPM_BRTH_DATE',
 'REGISTER_CORP',
 'EXISTING_CAR',
 'FINANCE_REQUIRED',
 'BKNG_NO',
 'BOOKING_DATE',
 'BKNG_AMT',
 'BOOKING_STATUS',
 'RCPT_NO',
 'RCPT_AMT',
 'PAYMENT_TYPE',
 'REGISTRATION_NAME',
 'EQRY_SR_NUM_REAL',
 'BOOKING_TYPE',
 'GRP_VRNT_CD',
 'EXT_COLOR_NAME',
 'INT_COLOR_NAME',
 'FINANCIER',
 'MODE_OF_PURCHASE',
 'BOOKING_CREATION_DATE',
 'BOOKING_CREATION_TIME',
 'BOOKING_UPDATE_DATE',
 'BOOKING_UPDATE_TIME',
 'TEST_DRIVE_DATE',
 'REQST_TYPE',
 'ENQUIRY_CATEGORY',
 'VEHICLE_BOOKED_COUNT',
 'LOSS_DATE',
 'LOSS_REMARK',
 'LOSS_REASON',
 'LOSS_DUETO',
 'LOSS_DUETO_DETAIL',
 'TEAM_LEADER',
 'REBKNG_CNT',
 'RCNT_REBKNG_DT',
 'MOB_DOCK',
 'VRNT_SPEC_CODE',
 'DMS_DOCK',
 'ORDER DATE',
 'ORDER_TYPE',
 'OEM',
 'MODL_MAKER_CODE',
 'MODL_MODEL_CODE',
 'OEM_MODEL',
 'CMM_GRP_CODE',
 'CMM_CODE_NAME',
 'CUDT_JOB_CODE',
 'Occ_Name'], axis=1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953461 entries, 0 to 953460
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   MOB_EMAIL_DATE  256450 non-null  object
#  1   DMS_EMAIL_DATE  429549 non-null  object
#  2   Dealer_Booking  953460 non-null  object
# dtypes: object(3)
# memory usage: 21.8+ MB

# %%
df.to_csv("C:\\Users\\15442\\Desktop\\Files\\ETL Through Code\\Modified files\\MOB_Docket_Date(m).csv",index=False)
