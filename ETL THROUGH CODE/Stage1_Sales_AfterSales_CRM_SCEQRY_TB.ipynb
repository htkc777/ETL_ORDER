# %%
! pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\15442\\Desktop\\Files\\ETL\\Stage1_Sales_AfterSales_CRM_SCEQRY_TB.csv')
# Out:
# C:\Users\15442\AppData\Local\Temp\ipykernel_19920\2067842348.py:1: DtypeWarning: Columns (25,32,33,34,35,42,43,50,58,64,65,71,72,73,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:\\Users\\15442\\Desktop\\Files\\ETL\\Stage1_Sales_AfterSales_CRM_SCEQRY_TB.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3457854 entries, 0 to 3457853
# Data columns (total 76 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   EQRY_DLR_NO             object
#  1   EQRY_ENQRY_NO           object
#  2   EQRY_CORP_NO            object
#  3   EQRY_CMPN_NO            object
#  4   EQRY_DATE               object
#  5   EQRY_SRC_CODE           object
#  6   EQRY_STAT               int64
#  7   EQRY_TYPE               object
#  8   EQRY_TEST_DRVR_DATE     float64
#  9   EQRY_FNCE_YN            object
#  10  EQRY_FNCER_CODE         object
#  11  EQRY_LOAN_AMT           float64
#  12  EQRY_TENOR_MNTHS        int64
#  13  EQRY_EXCHG_YN           object
#  14  EQRY_EXCHG_MODEL_CODE   object
#  15  EQRY_EXCHG_SRC_CODE     float64
#  16  EQRY_EXPCT_PRICE        float64
#  17  EQRY_QUOTD_PRICE        float64
#  18  EQRY_CLSE_DATE          object
#  19  EQRY_CLSE_TYPE          float64
#  20  EQRY_CLSE_RMRKS         object
# ...

# %%
df.shape
# Out:
# (3457854, 76)

# %%
df.isna().sum()
# Out:
# EQRY_DLR_NO             0
# EQRY_ENQRY_NO           0
# EQRY_CORP_NO            0
# EQRY_CMPN_NO            0
# EQRY_DATE               0
#                    ...
# SOQ_TAG_YN        3355301
# EQRY_EVAL_YN      3395079
# EQRY_EXCH_DN      3426136
# EQRY_FINAL_BP     3344650
# EQRY_CAMPGN_NO    3457853
# Length: 76, dtype: int64

# %%
list = []
for i in df:
    if df[i].isna().sum() == 3457854:
        list.append(i)

# %%
list
# Out:
# ['EQRY_TEST_DRVR_DATE',
#  'EQRY_UPDT_DATE',
#  'EQRY_TD_VIN',
#  'EQRY_REFL_ID',
#  'EQRY_REFL_PUNCH_DLR_NO',
#  'EQRY_PLAN_DATE',
#  'EQRY_ATIVT_LOC_CODE',
#  'EQRY_APNT_DTIME',
#  'VIST_DTIME',
#  'LEAV_DTIME',
#  'EQRY_BUDG_TYPE',
#  'EQRY_UC_SC_EMP_NO',
#  'EQRY_EMAILSEND_YN']

# %%
df.drop(['EQRY_TEST_DRVR_DATE',
 'EQRY_TD_VIN',
 'EQRY_REFL_ID',
 'EQRY_REFL_PUNCH_DLR_NO',
 'EQRY_PLAN_DATE',
 'EQRY_ATIVT_LOC_CODE',
 'EQRY_APNT_DTIME',
 'VIST_DTIME',
 'LEAV_DTIME',
 'EQRY_BUDG_TYPE',
 'EQRY_UC_SC_EMP_NO',
 'EQRY_EMAILSEND_YN'], axis=1, inplace = True)

# %%
df.shape
# Out:
# (3457854, 64)

# %%
df['Key'] = df['EQRY_ENQRY_NO']+df['EQRY_DLR_NO']

# %%
df
# Out:
#         EQRY_DLR_NO EQRY_ENQRY_NO EQRY_CORP_NO EQRY_CMPN_NO   EQRY_DATE  \
# 0           TRAP302    E201900003        A10VA            K  2019-07-15
# 1           TRUP403    E201900001        A10VA            K  2019-07-15
# 2           TRUP403    E201900003        A10VA            K  2019-07-15
# 3           TRUP403    E201900006        A10VA            K  2019-07-16
# 4           TRUP403    E201900007        A10VA            K  2019-07-16
# ...             ...           ...          ...          ...         ...
# 3457849     TRKA310    E202202843        A10VA            K  2022-08-06
# 3457850     TRKA403    E202208509        A10VA            K  2022-08-06
# 3457851     TRJH501    E202200622        A10VA            K  2022-08-06
# 3457852     TRTN403    E202206171        A10VA            K  2022-08-06
# 3457853     TRMH406    E202207137        A10VA            K  2022-08-06
#
#         EQRY_SRC_CODE  EQRY_STAT EQRY_TYPE EQRY_FNCE_YN EQRY_FNCER_CODE  ...  \
# ...

# %%
df["EQRY_SRC_FLG"] = df["EQRY_SRC_FLG"].astype(str)

# %%
df['EQRY_SRC_FLG']
# Out:
# 0          MOB
# 1          nan
# 2          nan
# 3          nan
# 4          nan
#           ...
# 3457849    MOB
# 3457850    MOB
# 3457851    MOB
# 3457852    MOB
# 3457853    MOB
# Name: EQRY_SRC_FLG, Length: 3457854, dtype: object

# %%
EQRY_SRC_FLG_list = []
for i in df["EQRY_SRC_FLG"]:
        EQRY_SRC_FLG_list.append(i)

# %%
for i in range(len(EQRY_SRC_FLG_list)):
    if EQRY_SRC_FLG_list[i] == 'MOB':
        EQRY_SRC_FLG_list[i] = 'MySales'

# %%
for i in range(len(EQRY_SRC_FLG_list)):
    if EQRY_SRC_FLG_list[i] != 'nan' and EQRY_SRC_FLG_list[i] != 'MySales':
        EQRY_SRC_FLG_list[i] = 'Online'
    elif EQRY_SRC_FLG_list[i] == 'nan':
        EQRY_SRC_FLG_list[i] = 'DMS'

# %%
df['Enquiry_Source_Type'] = EQRY_SRC_FLG_list

# %%
df['EQRY_FNCE_YN']
# Out:
# 0            N
# 1          NaN
# 2            N
# 3            N
# 4            N
#           ...
# 3457849      N
# 3457850      N
# 3457851      N
# 3457852      N
# 3457853      N
# Name: EQRY_FNCE_YN, Length: 3457854, dtype: object

# %%
df['Finance/Not Finance'] = df['EQRY_FNCE_YN'].apply(lambda x: 'Finance' if x == 'Y' else 'Not-Finance')

# %%
df['Finance/Not Finance']
# Out:
# 0          Not-Finance
# 1          Not-Finance
# 2          Not-Finance
# 3          Not-Finance
# 4          Not-Finance
#               ...
# 3457849    Not-Finance
# 3457850    Not-Finance
# 3457851    Not-Finance
# 3457852    Not-Finance
# 3457853    Not-Finance
# Name: Finance/Not Finance, Length: 3457854, dtype: object

# %%
# result = df[df['Finance/Not Finance']=='Finance']

# %%
# result

# %%
appMap1 = pd.read_csv('C:\\Users\\15442\\Desktop\\Files\\ETL Through Code\\Modified files\\3rd Table\\ENSC_NAME(m).csv')

# %%
appMap2 = pd.read_csv('C:\\Users\\15442\\Desktop\\Files\\ETL Through Code\\Modified files\\3rd Table\\ENSC_GRP_NAME(m).csv')

# %%
appMap1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EQRY_SUB_SRC_CODE  17 non-null     int64
#  1   ENSC_NAME          17 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 400.0+ bytes

# %%
appMap2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EQRY_SUB_SRC_CODE  17 non-null     int64
#  1   ENSC_GRP_NAME      17 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 400.0+ bytes

# %%
df.shape
# Out:
# (3457854, 67)

# %%
# df['EQRY_SUB_SRC_CODE'].isna().sum()

# %%
appMap1.shape
# Out:
# (17, 2)

# %%
# n_df = pd.merge(df, appMap1, how='left', on=['EQRY_SUB_SRC_CODE']).groupby(['EQRY_SUB_SRC_CODE']).first().reset_index()

# %%
# n_df.shape

# %%
# n_df

# %%
n1_df = pd.merge(df, appMap1, how='left', on=['EQRY_SUB_SRC_CODE'])

# %%
n1_df.shape
# Out:
# (3457854, 68)

# %%
n1_df
# Out:
#         EQRY_DLR_NO EQRY_ENQRY_NO EQRY_CORP_NO EQRY_CMPN_NO   EQRY_DATE  \
# 0           TRAP302    E201900003        A10VA            K  2019-07-15
# 1           TRUP403    E201900001        A10VA            K  2019-07-15
# 2           TRUP403    E201900003        A10VA            K  2019-07-15
# 3           TRUP403    E201900006        A10VA            K  2019-07-16
# 4           TRUP403    E201900007        A10VA            K  2019-07-16
# ...             ...           ...          ...          ...         ...
# 3457849     TRKA310    E202202843        A10VA            K  2022-08-06
# 3457850     TRKA403    E202208509        A10VA            K  2022-08-06
# 3457851     TRJH501    E202200622        A10VA            K  2022-08-06
# 3457852     TRTN403    E202206171        A10VA            K  2022-08-06
# 3457853     TRMH406    E202207137        A10VA            K  2022-08-06
#
#         EQRY_SRC_CODE  EQRY_STAT EQRY_TYPE EQRY_FNCE_YN EQRY_FNCER_CODE  ...  \
# ...

# %%
n1_df['EQRY_SUB_SRC_CODE']
# Out:
# 0          40
# 1          16
# 2           8
# 3           1
# 4           8
#            ..
# 3457849     7
# 3457850     1
# 3457851     1
# 3457852     7
# 3457853     7
# Name: EQRY_SUB_SRC_CODE, Length: 3457854, dtype: object

# %%
n1_df.shape
# Out:
# (3457854, 68)

# %%
n1_df["ENSC_NAME"] = n1_df["ENSC_NAME"].astype(str)

# %%
n1_df['ENSC_NAME'] = n1_df['ENSC_NAME'].apply(lambda x: 'ADVERTISEMENTS' if x == 'Ads' else x.upper())

# %%
n1_df['ENSC_NAME']
# Out:
# 0                DEALER WEBSITE
# 1          HAPPINESS CHECK LIST
# 2                      REFERRAL
# 3                 INBOUND CALLS
# 4                      REFERRAL
#                    ...
# 3457849          ADVERTISEMENTS
# 3457850           INBOUND CALLS
# 3457851           INBOUND CALLS
# 3457852          ADVERTISEMENTS
# 3457853          ADVERTISEMENTS
# Name: ENSC_NAME, Length: 3457854, dtype: object

# %%
n1_df.rename(columns={"ENSC_NAME":"Enquiry_Sub_Source_Name"},inplace = True)

# %%
n1_df.shape
# Out:
# (3457854, 68)

# %%
n2_df = pd.merge(n1_df, appMap2, how='left', on=['EQRY_SUB_SRC_CODE'])

# %%
n2_df.shape
# Out:
# (3457854, 69)

# %%
n2_df
# Out:
#         EQRY_DLR_NO EQRY_ENQRY_NO EQRY_CORP_NO EQRY_CMPN_NO   EQRY_DATE  \
# 0           TRAP302    E201900003        A10VA            K  2019-07-15
# 1           TRUP403    E201900001        A10VA            K  2019-07-15
# 2           TRUP403    E201900003        A10VA            K  2019-07-15
# 3           TRUP403    E201900006        A10VA            K  2019-07-16
# 4           TRUP403    E201900007        A10VA            K  2019-07-16
# ...             ...           ...          ...          ...         ...
# 3457849     TRKA310    E202202843        A10VA            K  2022-08-06
# 3457850     TRKA403    E202208509        A10VA            K  2022-08-06
# 3457851     TRJH501    E202200622        A10VA            K  2022-08-06
# 3457852     TRTN403    E202206171        A10VA            K  2022-08-06
# 3457853     TRMH406    E202207137        A10VA            K  2022-08-06
#
#         EQRY_SRC_CODE  EQRY_STAT EQRY_TYPE EQRY_FNCE_YN EQRY_FNCER_CODE  ...  \
# ...

# %%
n2_df["ENSC_GRP_NAME"] = n2_df["ENSC_GRP_NAME"].astype(str)

# %%
n2_df['Enquiry_Source'] = n2_df['ENSC_GRP_NAME'].str.upper()

# %%
df_next1 = pd.read_csv('C:\\Users\\15442\\Desktop\\Files\\ETL Through Code\\Modified files\\3rd Table\\Enquiry_Status(m).csv')

# %%
n2_df.shape
# Out:
# (3457854, 70)

# %%
df_next1.shape
# Out:
# (20, 2)

# %%
df_next1
# Out:
#     EQRY_STAT                    CMM_CODE_NAME
# 0          10                          Enquiry
# 1          20                          Booking
# 2          30                       Assignment
# 3          40                          Invoice
# 4          45                           Retail
# 5          50                   Enquiry Cancel
# 6          60                   Booking Cancel
# 7          70                Assignment Cancel
# 8          80                   Invoice Cancel
# 9          90                             Lost
# 10         15                       Prebooking
# 11         86  Appointed cancellation approval
# 12         55         Appointed Enquiry Cancel
# 13         57          Customer Meeting Cancel
# 14         59         Enquiry Follow up Cancel
# 15         85    Enquiry cancellation approval
# 16          1                             Lead
# 17          5                Appointed Enquiry
# 18          7                 Customer Meeting
# ...

# %%
merge1 = pd.merge(n2_df, df_next1, how='left', on=['EQRY_STAT'])

# %%
merge1.shape
# Out:
# (3457854, 71)

# %%
merge1.rename(columns = {'CMM_CODE_NAME':'Enquiry_Status'}, inplace = True)

# %%
merge1
# Out:
#         EQRY_DLR_NO EQRY_ENQRY_NO EQRY_CORP_NO EQRY_CMPN_NO   EQRY_DATE  \
# 0           TRAP302    E201900003        A10VA            K  2019-07-15
# 1           TRUP403    E201900001        A10VA            K  2019-07-15
# 2           TRUP403    E201900003        A10VA            K  2019-07-15
# 3           TRUP403    E201900006        A10VA            K  2019-07-16
# 4           TRUP403    E201900007        A10VA            K  2019-07-16
# ...             ...           ...          ...          ...         ...
# 3457849     TRKA310    E202202843        A10VA            K  2022-08-06
# 3457850     TRKA403    E202208509        A10VA            K  2022-08-06
# 3457851     TRJH501    E202200622        A10VA            K  2022-08-06
# 3457852     TRTN403    E202206171        A10VA            K  2022-08-06
# 3457853     TRMH406    E202207137        A10VA            K  2022-08-06
#
#         EQRY_SRC_CODE  EQRY_STAT EQRY_TYPE EQRY_FNCE_YN EQRY_FNCER_CODE  ...  \
# ...

# %%
df_next2 = pd.read_csv('C:\\Users\\15442\\Desktop\\Files\\ETL Through Code\\Modified files\\3rd Table\\Enquiry_Type2(m).csv')

# %%
merge1.shape
# Out:
# (3457854, 71)

# %%
df_next2.shape
# Out:
# (3, 2)

# %%
df_next2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EQRY_TYPE      3 non-null      object
#  1   CMM_CODE_NAME  3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes

# %%
merge2 = pd.merge(merge1, df_next2, how='left', on=['EQRY_TYPE'])

# %%
merge2.shape
# Out:
# (3457854, 72)

# %%
merge2.rename(columns = {'CMM_CODE_NAME':'Enquiry_Type2'}, inplace = True)

# %%
merge2
# Out:
#         EQRY_DLR_NO EQRY_ENQRY_NO EQRY_CORP_NO EQRY_CMPN_NO   EQRY_DATE  \
# 0           TRAP302    E201900003        A10VA            K  2019-07-15
# 1           TRUP403    E201900001        A10VA            K  2019-07-15
# 2           TRUP403    E201900003        A10VA            K  2019-07-15
# 3           TRUP403    E201900006        A10VA            K  2019-07-16
# 4           TRUP403    E201900007        A10VA            K  2019-07-16
# ...             ...           ...          ...          ...         ...
# 3457849     TRKA310    E202202843        A10VA            K  2022-08-06
# 3457850     TRKA403    E202208509        A10VA            K  2022-08-06
# 3457851     TRJH501    E202200622        A10VA            K  2022-08-06
# 3457852     TRTN403    E202206171        A10VA            K  2022-08-06
# 3457853     TRMH406    E202207137        A10VA            K  2022-08-06
#
#         EQRY_SRC_CODE  EQRY_STAT EQRY_TYPE EQRY_FNCE_YN EQRY_FNCER_CODE  ...  \
# ...

# %%
df_next3 = pd.read_csv('C:\\Users\\15442\\Desktop\\Files\\ETL Through Code\\Modified files\\3rd Table\\Enquiry_Category_Type(m).csv')

# %%
merge2.shape
# Out:
# (3457854, 72)

# %%
df_next3.shape
# Out:
# (20, 2)

# %%
df_next3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EQRY_CTGR_CODE  20 non-null     int64
#  1   CMM_CODE_NAME   20 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
merge3 = pd.merge(merge2, df_next3, how='left', on=['EQRY_CTGR_CODE'])

# %%
merge3.shape
# Out:
# (3457854, 73)

# %%
merge3
# Out:
#         EQRY_DLR_NO EQRY_ENQRY_NO EQRY_CORP_NO EQRY_CMPN_NO   EQRY_DATE  \
# 0           TRAP302    E201900003        A10VA            K  2019-07-15
# 1           TRUP403    E201900001        A10VA            K  2019-07-15
# 2           TRUP403    E201900003        A10VA            K  2019-07-15
# 3           TRUP403    E201900006        A10VA            K  2019-07-16
# 4           TRUP403    E201900007        A10VA            K  2019-07-16
# ...             ...           ...          ...          ...         ...
# 3457849     TRKA310    E202202843        A10VA            K  2022-08-06
# 3457850     TRKA403    E202208509        A10VA            K  2022-08-06
# 3457851     TRJH501    E202200622        A10VA            K  2022-08-06
# 3457852     TRTN403    E202206171        A10VA            K  2022-08-06
# 3457853     TRMH406    E202207137        A10VA            K  2022-08-06
#
#         EQRY_SRC_CODE  EQRY_STAT EQRY_TYPE EQRY_FNCE_YN EQRY_FNCER_CODE  ...  \
# ...

# %%
merge3.rename(columns = {'CMM_CODE_NAME':'Enquiry_Category_Type'}, inplace = True)

# %%
merge3.columns
# Out:
# Index(['EQRY_DLR_NO', 'EQRY_ENQRY_NO', 'EQRY_CORP_NO', 'EQRY_CMPN_NO',
#        'EQRY_DATE', 'EQRY_SRC_CODE', 'EQRY_STAT', 'EQRY_TYPE', 'EQRY_FNCE_YN',
#        'EQRY_FNCER_CODE', 'EQRY_LOAN_AMT', 'EQRY_TENOR_MNTHS', 'EQRY_EXCHG_YN',
#        'EQRY_EXCHG_MODEL_CODE', 'EQRY_EXCHG_SRC_CODE', 'EQRY_EXPCT_PRICE',
#        'EQRY_QUOTD_PRICE', 'EQRY_CLSE_DATE', 'EQRY_CLSE_TYPE',
#        'EQRY_CLSE_RMRKS', 'EQRY_EMP_NO', 'EQRY_CUST_NO', 'EQRY_LISTD_CORP',
#        'EQRY_CORP_NAME', 'EQRY_RFRL_BY', 'EQRY_CRTE_DTIME', 'EQRY_CRTE_EMP_NO',
#        'EQRY_UPDT_DTIME', 'EQRY_UPDT_EMP_NO', 'EQRY_EQFU_SEQ',
#        'EQRY_UPDT_DATE', 'EQRY_TEST_DRIVE_YN', 'EQRY_SR_NUM', 'EQRY_SR_TYPE',
#        'EQRY_FLW_STATUS', 'EQRY_ASSOCIATE_ID', 'EQRY_RSO_ID', 'EQRY_FUEL_TYPE',
#        'EQRY_PRESENT_CAR_YN', 'EQRY_MAKER_CODE', 'EQRY_CUST_BLOCK',
#        'EQRY_BULK_SALE', 'EQRY_P_MODL_YEAR', 'EQRY_CLS_VAL',
#        'EQRY_INCOM_GROUP', 'EQRY_ATIVT_NAME_CODE', 'EQRY_NEWCAR_YN',
# ...
