# %%
! pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\15442\\Desktop\\Files\\ETL\\Sales_Team_Leader.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3436397 entries, 0 to 3436396
# Data columns (total 10 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   TEAM_LEADER               object
#  1   TEAM_LEADER_JOINING_DATE  object
#  2   TEAM_LEADER_LEAVE_DATE    object
#  3   KEC                       object
#  4   KEC_NAME                  object
#  5   KEC_CODE                  object
#  6   KEC_JOIN_DATE             object
#  7   KEC_LEAVE_DATE            object
#  8   EQRY_ENQRY_NO             object
#  9   EQRY_DLR_NO               object
# dtypes: object(10)
# memory usage: 262.2+ MB

# %%
df.shape
# Out:
# (3436397, 10)

# %%
df.isna().sum()
# Out:
# TEAM_LEADER                 1149841
# TEAM_LEADER_JOINING_DATE    1149841
# TEAM_LEADER_LEAVE_DATE      3425486
# KEC                            7367
# KEC_NAME                       7445
# KEC_CODE                          0
# KEC_JOIN_DATE                  7449
# KEC_LEAVE_DATE              2405469
# EQRY_ENQRY_NO                     0
# EQRY_DLR_NO                       0
# dtype: int64

# %%
df
# Out:
#                                           TEAM_LEADER  \
# 0                                                 NaN
# 1                                                 NaN
# 2                     EUP4030014;VISHAL SHARMA;Active
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 3436392                                           NaN
# 3436393                ERJ3020004;Mohit Sharma;Active
# 3436394                EPB1010017;RAJBIR SINGH;Active
# 3436395  EMH4100076;LAXMIKANT RAMSIRJAN PANDEY;Active
# 3436396     EMH4050061;Amol Chandrakant Chavan;Active
#
#         TEAM_LEADER_JOINING_DATE TEAM_LEADER_LEAVE_DATE         KEC  \
# 0                            NaN                    NaN  EAP3020001
# 1                            NaN                    NaN  EUP4030004
# 2                     2019-07-14                    NaN  EUP4030002
# ...

# %%
df['TEAM_LEADER']
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                       EUP4030014;VISHAL SHARMA;Active
# 3                                                   NaN
# 4                                                   NaN
#                                ...
# 3436392                                             NaN
# 3436393                  ERJ3020004;Mohit Sharma;Active
# 3436394                  EPB1010017;RAJBIR SINGH;Active
# 3436395    EMH4100076;LAXMIKANT RAMSIRJAN PANDEY;Active
# 3436396       EMH4050061;Amol Chandrakant Chavan;Active
# Name: TEAM_LEADER, Length: 3436397, dtype: object

# %%
# for i in df['TEAM_LEADER']:
#     if i != 'nan':
#         print(f"{i} ----------------------- {type(i)}")

# %%
df['TEAM_LEADER'] = df["TEAM_LEADER"].map(str)

# %%
# for i in df['TEAM_LEADER']:
# #     if i != 'nan':
#         print(f"{i} ----------------------- {type(i)}")

# %%
Team_Leader_Code = []
Team_Leader_Name = []
Active_Inactive = []

# %%
for i in df['TEAM_LEADER']:
    x = i.split(';')
    y = x[0]
    Team_Leader_Code.append(y)

# %%
Team_Leader_Code
# Out:
# ['nan',
#  'nan',
#  'EUP4030014',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'EKA4050088',
#  'EKA4050052',
#  'nan',
#  'nan',
#  'ETS4030013',
#  'ETS4010260',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'EWB4020097',
#  'nan',
#  'nan',
#  'EMH3020049',
#  'EKA4050200',
#  'ERJ4030107',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'EMH3020049',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'EMH3020049',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'EKL3040014',
#  'nan',
#  'nan',
#  'EMH3020049',
#  'EKA4050052',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'EGJ3040104',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'EMH4010017',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'EMH3020049',
#  'nan',
#  'nan',
# ...

# %%
df['Team_Leader_Code'] = Team_Leader_Code

# %%
df
# Out:
#                                           TEAM_LEADER  \
# 0                                                 nan
# 1                                                 nan
# 2                     EUP4030014;VISHAL SHARMA;Active
# 3                                                 nan
# 4                                                 nan
# ...                                               ...
# 3436392                                           nan
# 3436393                ERJ3020004;Mohit Sharma;Active
# 3436394                EPB1010017;RAJBIR SINGH;Active
# 3436395  EMH4100076;LAXMIKANT RAMSIRJAN PANDEY;Active
# 3436396     EMH4050061;Amol Chandrakant Chavan;Active
#
#         TEAM_LEADER_JOINING_DATE TEAM_LEADER_LEAVE_DATE         KEC  \
# 0                            NaN                    NaN  EAP3020001
# 1                            NaN                    NaN  EUP4030004
# 2                     2019-07-14                    NaN  EUP4030002
# ...

# %%
for i in df['TEAM_LEADER']:
    x = i.split(';')
    if len(x) == 1:
        y = x[0]
        Team_Leader_Name.append(y)
    else:
        z = x[1]
        Team_Leader_Name.append(z.upper())

# %%
Team_Leader_Name
# Out:
# ['nan',
#  'nan',
#  'VISHAL SHARMA',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'ASHWIN BELTHUR M',
#  'CHETHAN R',
#  'nan',
#  'nan',
#  'ABHINAV DINTAKURTHI',
#  'PAILA GOPI KRISHNA',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'AMIT UKIL',
#  'nan',
#  'nan',
#  'SANJAY MOTIRAM MUNGE ',
#  'RANJITH J',
#  'HIMMAT SINGH',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'SANJAY MOTIRAM MUNGE ',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'SANJAY MOTIRAM MUNGE ',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'JITHIN S',
#  'nan',
#  'nan',
#  'SANJAY MOTIRAM MUNGE ',
#  'CHETHAN R',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'HARDIK HINGU',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'RAJSHRI PATARE',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
# ...

# %%
df['Team_Leader_Name'] = Team_Leader_Name

# %%
for i in df['TEAM_LEADER']:
    x = i.split(';')
    if len(x) == 1:
        y = x[0]
        Active_Inactive.append(y)
    else:
        z = x[2]
        Active_Inactive.append(z.upper())

# %%
df['Active_Inactive'] = Active_Inactive

# %%
df.rename(columns = {'KEC':'KEC_Short_Code'}, inplace = True)

# %%
df['KEC'] = df['KEC_NAME'].str.upper()

# %%
df.rename(columns = {'KEC_CODE':'KEC_Long_Code'}, inplace = True)

# %%
df.rename(columns = {'TEAM_LEADER_LEAVE_DATE':'Team_leader_Leave_Date'}, inplace = True)

# %%
df.rename(columns = {'KEC_JOIN_DATE':'KEC_Join_Date'}, inplace = True)

# %%
df.rename(columns = {'KEC_LEAVE_DATE':'KEC_Leave_Date'}, inplace = True)

# %%
df.rename(columns = {'TEAM_LEADER_JOINING_DATE':'Team_leader_Joining_Date'}, inplace = True)

# %%
df.rename(columns = {'EQRY_ENQRY_NO':'Link_Enquiry_No'}, inplace = True)

# %%
df.rename(columns = {'EQRY_DLR_NO':'Dealer_No'}, inplace = True)

# %%
df.rename(columns = {'Active_Inactive':'Active/Inactive'}, inplace = True)

# %%
df
# Out:
#                                           TEAM_LEADER  \
# 0                                                 nan
# 1                                                 nan
# 2                     EUP4030014;VISHAL SHARMA;Active
# 3                                                 nan
# 4                                                 nan
# ...                                               ...
# 3436392                                           nan
# 3436393                ERJ3020004;Mohit Sharma;Active
# 3436394                EPB1010017;RAJBIR SINGH;Active
# 3436395  EMH4100076;LAXMIKANT RAMSIRJAN PANDEY;Active
# 3436396     EMH4050061;Amol Chandrakant Chavan;Active
#
#         Team_leader_Joining_Date Team_leader_Leave_Date KEC_Short_Code  \
# 0                            NaN                    NaN     EAP3020001
# 1                            NaN                    NaN     EUP4030004
# 2                     2019-07-14                    NaN     EUP4030002
# ...

# %%
# df.to_csv("C:\\Users\\15442\\Desktop\\Files\\ETL Through Code\\Modified files\\Sales_Team_Leader(m).csv",index=False)
